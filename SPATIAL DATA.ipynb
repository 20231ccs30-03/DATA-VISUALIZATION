# %% [markdown]
# <a href="https://colab.research.google.com/github/Kotni-Ranjith/DATA-VISUALIZATION/blob/main/SPATIAL%20DATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
mymap=folium.Map(location=[13.172678003686375, 77.5359020080475],
                 width=950,
                 height=550,
                 zoom_start=12,
                 tiles='openstreetmap')
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27fbb5afac004ec8bf1b2c0a261cd45c {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27fbb5afac004ec8bf1b2c0a261cd45c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27fbb5afac004ec8bf1b2c0a261cd45c = L.map(
#                 &quot;map_27fbb5afac004ec8bf1b2c0a261cd45c&quot;,
#                 {
#                     center: [13.172678003686375, 77.5359020080475],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5ed8599af7ec70af89de96145d5f11a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_27fbb5afac004ec8bf1b2c0a261cd45c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
latitude = 13.172678003686375
longitude =77.5359020080475


mymap = folium.Map(location=[latitude, longitude], zoom_start=12)


image_url = 'https://media.licdn.com/dms/image/C561BAQHA2-sfph3y7Q/company-background_10000/0/1585975556591/presidency_university_india_cover?e=2147483647&v=beta&t=_s7SRUHAtTLOEdPOQ50Slacd87gqK3ipDDhQONP7wyk'

def image_popup_html(image_url, name):
    html = f"""
    <div>
        <h3>{name}</h3>
        <img src="{image_url}" width="150" height="150">
    </div>
    """
    return html


folium.Marker(
    location=[latitude, longitude],
    popup=folium.Popup(image_popup_html(image_url, "Presidency University,Banglore"), max_width=200),
    tooltip="Click me!"
).add_to(mymap)

mymap.save("my_map_with_custom_marker.html")
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca97a0be5889b19306488e3e31112296 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca97a0be5889b19306488e3e31112296&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca97a0be5889b19306488e3e31112296 = L.map(
#                 &quot;map_ca97a0be5889b19306488e3e31112296&quot;,
#                 {
#                     center: [13.172678003686375, 77.5359020080475],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b33daf8ce7ec3fd8afb719400f753f56 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ca97a0be5889b19306488e3e31112296);
#
#
#             var marker_45f0a81562c3dc0d264cbbdc311d50da = L.marker(
#                 [13.172678003686375, 77.5359020080475],
#                 {}
#             ).addTo(map_ca97a0be5889b19306488e3e31112296);
#
#
#         var popup_de680a3cb704874e6e2e250d29430292 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_4482f153e00cc272f379ad48fd183938 = $(`&lt;div id=&quot;html_4482f153e00cc272f379ad48fd183938&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div&gt;         &lt;h3&gt;Presidency University,Banglore&lt;/h3&gt;         &lt;img src=&quot;https://media.licdn.com/dms/image/C561BAQHA2-sfph3y7Q/company-background_10000/0/1585975556591/presidency_university_india_cover?e=2147483647&amp;v=beta&amp;t=_s7SRUHAtTLOEdPOQ50Slacd87gqK3ipDDhQONP7wyk&quot; width=&quot;150&quot; height=&quot;150&quot;&gt;     &lt;/div&gt;     &lt;/div&gt;`)[0];
#                 popup_de680a3cb704874e6e2e250d29430292.setContent(html_4482f153e00cc272f379ad48fd183938);
#
#
#
#         marker_45f0a81562c3dc0d264cbbdc311d50da.bindPopup(popup_de680a3cb704874e6e2e250d29430292)
#         ;
#
#
#
#
#             marker_45f0a81562c3dc0d264cbbdc311d50da.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
latitude=12.9716
longitude=77.5946
m=folium.Map(location=[latitude,longitude],zomm_start=12)
locations=[
    {"name":"banglore palace","latitude":12.996765297272566,"longitude":77.5921279388172},
    {"name":"vidan soudha","latitude":12.979777253298169,"longitude":77.59070795230727},
    {"name":"iisc","latitude":13.017243975116598,"longitude":77.56712358114449},
]
for location in locations:
  folium.Marker(
      [location["latitude"],location["longitude"]],popup=location["name"]
  ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74f65b859064e2b9dc0b9db81fd01bf1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74f65b859064e2b9dc0b9db81fd01bf1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74f65b859064e2b9dc0b9db81fd01bf1 = L.map(
#                 &quot;map_74f65b859064e2b9dc0b9db81fd01bf1&quot;,
#                 {
#                     center: [12.9716, 77.5946],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     zommStart: 12,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef85b6caf304a18b1652fbd5031f9967 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74f65b859064e2b9dc0b9db81fd01bf1);
#
#
#             var marker_64c5f75b87cebc418e5458e37176bb42 = L.marker(
#                 [12.996765297272566, 77.5921279388172],
#                 {}
#             ).addTo(map_74f65b859064e2b9dc0b9db81fd01bf1);
#
#
#         var popup_fddcb13d851fb40f2d95b7fa6e38b679 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb9cfcfd1d003d8329dcc2c57bc8e9a3 = $(`&lt;div id=&quot;html_fb9cfcfd1d003d8329dcc2c57bc8e9a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;banglore palace&lt;/div&gt;`)[0];
#                 popup_fddcb13d851fb40f2d95b7fa6e38b679.setContent(html_fb9cfcfd1d003d8329dcc2c57bc8e9a3);
#
#
#
#         marker_64c5f75b87cebc418e5458e37176bb42.bindPopup(popup_fddcb13d851fb40f2d95b7fa6e38b679)
#         ;
#
#
#
#
#             var marker_5ca34547bcea8edc37f4a159dd969b7c = L.marker(
#                 [12.979777253298169, 77.59070795230727],
#                 {}
#             ).addTo(map_74f65b859064e2b9dc0b9db81fd01bf1);
#
#
#         var popup_181222f2e96e792bf819dc9b4ba7ba11 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c75e2100a408b333900d11539a911561 = $(`&lt;div id=&quot;html_c75e2100a408b333900d11539a911561&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;vidan soudha&lt;/div&gt;`)[0];
#                 popup_181222f2e96e792bf819dc9b4ba7ba11.setContent(html_c75e2100a408b333900d11539a911561);
#
#
#
#         marker_5ca34547bcea8edc37f4a159dd969b7c.bindPopup(popup_181222f2e96e792bf819dc9b4ba7ba11)
#         ;
#
#
#
#
#             var marker_ebb1b9b5d318099d41ac7a219cd1a148 = L.marker(
#                 [13.017243975116598, 77.56712358114449],
#                 {}
#             ).addTo(map_74f65b859064e2b9dc0b9db81fd01bf1);
#
#
#         var popup_2d00c820f8e05cbbaf1fc365af13b0a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_76411915c0309879d9ce6cfdb03ce514 = $(`&lt;div id=&quot;html_76411915c0309879d9ce6cfdb03ce514&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;iisc&lt;/div&gt;`)[0];
#                 popup_2d00c820f8e05cbbaf1fc365af13b0a0.setContent(html_76411915c0309879d9ce6cfdb03ce514);
#
#
#
#         marker_ebb1b9b5d318099d41ac7a219cd1a148.bindPopup(popup_2d00c820f8e05cbbaf1fc365af13b0a0)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
