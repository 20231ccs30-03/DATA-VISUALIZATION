# %% [markdown]
# <a href="https://colab.research.google.com/github/Kotni-Ranjith/DATA-VISUALIZATION/blob/main/WEB%20SCRAPING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
Link='https://parade.com/1003052/samuelmurrian/best-movie-posters/'
Link_text=requests.get(Link).text
print(Link_text)
# Out:
# <html><head><title>parade.com</title><style>#cmsg{animation: A 1.5s;}@keyframes A{0%{opacity:0;}99%{opacity:0;}100%{opacity:1;}}</style></head><body style="margin:0"><p id="cmsg">Please enable JS and disable any ad blocker</p><script data-cfasync="false">var dd={'rt':'c','cid':'AHrlqAAAAAMAV138ZkcmMF4AI7k4hg==','hsh':'2AC20A4365547ED96AE26618B66966','t':'bv','s':41010,'e':'75f852a4b4f4bf352560bddc2d7b2133c6b9223c0b283cfcfa711ff7a437c05c','host':'geo.captcha-delivery.com'}</script><script data-cfasync="false" src="https://ct.captcha-delivery.com/c.js"></script></body></html>

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(Link_text,'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="320" name="MobileOptimized"/>
# <meta content="initial-scale=1.0, width=device-width, minimum-scale=1.0, user-scalable=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://robbreport.com/xmlrpc.php" rel="pingback"/>
# <meta content="445395315547478" property="fb:app_id"/>
# <!--
# 		 _     _ _           ____          _          _____ _    ___
# 		| |   (_) | _____   / ___|___   __| | ___    | ____| |__|__ \
# 		| |   | | |/ / _ \ | |   / _ \ / _` |/ _ \   |  _| | '_ \ / /
# 		| |___| |   <  __/ | |__| (_) | (_| |  __/_  | |___| | | |_|
# 		|_____|_|_|\_\___|  \____\___/ \__,_|\___( ) |_____|_| |_(_)
# 												  |/
#
# 		 Work on Robb Report and other iconic brands!
#
# 		 Visit our careers page at https://pmc.com/careers/
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
import os

def extract_images(url, save_folder):
    # Make a GET request to the URL
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all image tags
        img_tags = soup.find_all('img')

        # Create a folder to save the images if it doesn't exist
        if not os.path.exists(save_folder):
            os.makedirs(save_folder)

        # Extract and save images
        for img_tag in img_tags:
            # Get the image source (URL)
            img_url = img_tag['src']

            # Get the image name
            img_name = os.path.basename(img_url)

            # Download the image
            img_data = requests.get(img_url).content

            # Save the image to the specified folder
            with open(os.path.join(save_folder, img_name), 'wb') as img_file:
                img_file.write(img_data)

        print("Images extracted and saved successfully!")
    else:
        print("Failed to fetch page content.")

# Example usage:
website_url = 'https://www.imdb.com/list/ls069457382/'
save_folder = 'images'
extract_images(website_url, save_folder)
# Out:
# Images extracted and saved successfully!

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="320" name="MobileOptimized"/>
# <meta content="initial-scale=1.0, width=device-width, minimum-scale=1.0, user-scalable=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://robbreport.com/xmlrpc.php" rel="pingback"/>
# <meta content="445395315547478" property="fb:app_id"/>
# <!--
# 		 _     _ _           ____          _          _____ _    ___
# 		| |   (_) | _____   / ___|___   __| | ___    | ____| |__|__ \
# 		| |   | | |/ / _ \ | |   / _ \ / _` |/ _ \   |  _| | '_ \ / /
# 		| |___| |   <  __/ | |__| (_) | (_| |  __/_  | |___| | | |_|
# 		|_____|_|_|\_\___|  \____\___/ \__,_|\___( ) |_____|_| |_(_)
# 												  |/
#
# 		 Work on Robb Report and other iconic brands!
#
# ...

# %%
print(soup.title)
# Out:
# <title>The 25 Greatest Supercars of the 21st Century (So Far)</title>

# %%
print(soup.title.string)
# Out:
# The 25 Greatest Supercars of the 21st Century (So Far)
